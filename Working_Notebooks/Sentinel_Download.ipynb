# %%
# %run "C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Sentinel_Download.py"

# %%
latitude = 68.948500
longitude = -131.365400
years = [2017,2018,2019,2020,2021,2022,2023,2024]
folder_path = 'Sentinel/s019'

sentinel_imagery(latitude,longitude,years,folder_path)
# Out:
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# Error retrieving image date. Likely no images below the cloud threshold. Image.select: Parameter 'input' is required.
# ...

# %%
display_tiff("C:\\Users\\cmeri\\Downloads\\sentinel2_lowest_cloud_week_1.tif")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:/Users/cmeri/Downloads/sentinel2_lowest_cloud_week_1.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 display_tiff("C:\\Users\\cmeri\\Downloads\\sentinel2_lowest_cloud_week_1.tif")
#
# File ~\OneDrive - Dartmouth College\Math_76\FinalProject\Math76_FinalProject\Sentinel_Download.py:89, in display_tiff(file_path, bands, stretch_percent)
#      80 def display_tiff(file_path, bands=(2, 3, 4), stretch_percent=2):
#      81     """
# ...

# %%
# %run "C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Process_TIFF.py"

# %%
process_folder("C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Data/Sentinel-s019")
# Out:
# Processing C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Data/Sentinel-s019\Sentinel2_2019-06-07.tif
# NDVI image saved as NDVI_2019-06-07.jpg
# RGBA image saved as RGBA_2019-06-07.png
# Processing C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Data/Sentinel-s019\Sentinel2_2019-06-09.tif
# NDVI image saved as NDVI_2019-06-09.jpg
# RGBA image saved as RGBA_2019-06-09.png
# Processing C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Data/Sentinel-s019\Sentinel2_2019-06-17.tif
# NDVI image saved as NDVI_2019-06-17.jpg
# RGBA image saved as RGBA_2019-06-17.png
# Processing C:/Users/cmeri/OneDrive - Dartmouth College/Math_76/FinalProject/Math76_FinalProject/Data/Sentinel-s019\Sentinel2_2019-06-22.tif
# NDVI image saved as NDVI_2019-06-22.jpg
# RGBA image saved as RGBA_2019-06-22.png
# ...
